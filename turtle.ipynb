# %% [markdown]
# <a href="https://colab.research.google.com/github/apicem7217/Clase8/blob/Phyton/turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=52a9a7fde4ad9d1c899e72c905f6d0a218ca9dec4e1540efd68cb300c5529ca5
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *

# %%
import ColabTurtle

# %%
initializeTurtle(initial_speed=7)
colors_list = ["red", "purple", "blue", "green", "orange", "yellow"]

for value in range(300):
  pencolor(colors_list[value%6])
  width(int(value/100)+1)
  forward(value/1.5)
  left(59)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
initializeTurtle(initial_speed=5)
forward(199)
left(90)
forward(50)
pencolor("azul")
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="51.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="51.0" x2="350.0" y2="51.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(270,350.0,51.0) translate(332.0, 33.0)">
# ...

# %%
initializeTurtle()
pencolor("red")
for i in range(3):
  forward(100)
  left(120)

#pencolor("blue")
#forward(200)
#pencolor("yellow")
#left(120)
#forward(200)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="200.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="313.397" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
initializeTurtle()
pencolor("blue")

lado = 5
tamaño = lado/2
for i in range(lado):
  forward(300/tamaño)
  left(360/lado)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
colors_list = ["red", "purple", "blue", "green", "orange", "yellow"]

colors_list[value%6]
# Out:
# 'yellow'

# %%
for value in range(10):
  print(colors_list[value%6])
left(100)
# Out:
# red
# purple
# blue
# green
# orange
# yellow
# red
# purple
# blue
# green
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
